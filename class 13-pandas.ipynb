# %%
import pandas as pd 
df = pd.read_csv('datas.csv')
df             
# df--(can be anything)
# Out:
#    sn   name  age address       phone
# 0   1  shyam   34     ktm   988736333
# 1   2   hari   23     pkr  9876273743
# 2   3  sabin   32     bkt  9835021830
# 3   4    ram   21     ktm  9846363733
# 4   5  nabin   44     pkr  9870184844
# 5   6  akash   31     bkt  9847385478

# %%
print(df.head())
# Out:
#    sn   name  age address       phone
# 0   1  shyam   34     ktm   988736333
# 1   2   hari   23     pkr  9876273743
# 2   3  sabin   32     bkt  9835021830
# 3   4    ram   21     ktm  9846363733
# 4   5  nabin   44     pkr  9870184844

# %%
df.head(3)
# Out:
#    sn   name  age address       phone
# 0   1  shyam   34     ktm   988736333
# 1   2   hari   23     pkr  9876273743
# 2   3  sabin   32     bkt  9835021830

# %%
df.tail(3)
# Out:
#    sn   name  age address       phone
# 3   4    ram   21     ktm  9846363733
# 4   5  nabin   44     pkr  9870184844
# 5   6  akash   31     bkt  9847385478

# %%
df.iloc[3:5]
# Out:
#    sn   name  age address       phone
# 3   4    ram   21     ktm  9846363733
# 4   5  nabin   44     pkr  9870184844

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'name')
df
# Out:
#        sn  age address       phone
# name
# shyam   1   34     ktm   988736333
# hari    2   23     pkr  9876273743
# sabin   3   32     bkt  9835021830
# ram     4   21     ktm  9846363733
# nabin   5   44     pkr  9870184844
# akash   6   31     bkt  9847385478

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df.loc[2:5]
# Out:
#      name  age address       phone
# sn
# 2    hari   23     pkr  9876273743
# 3   sabin   32     bkt  9835021830
# 4     ram   21     ktm  9846363733
# 5   nabin   44     pkr  9870184844

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'name')
df ['sabin':'nabin']
# Out:
#        sn  age address       phone
# name
# sabin   3   32     bkt  9835021830
# ram     4   21     ktm  9846363733
# nabin   5   44     pkr  9870184844

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df ['name']
# Out:
# sn
# 1    shyam
# 2     hari
# 3    sabin
# 4      ram
# 5    nabin
# 6    akash
# Name: name, dtype: object

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df ['address'] == 'ktm'
# Out:
# sn
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# Name: address, dtype: bool

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df[df ['address'] == 'ktm']
# Out:
#      name  age address       phone
# sn
# 1   shyam   34     ktm   988736333
# 4     ram   21     ktm  9846363733

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df[df ['age'] > 35]
# Out:
#      name  age address       phone
# sn
# 5   nabin   44     pkr  9870184844

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
df[(df ['age'] > 20) & (df['age'] < 30)]
# Out:
#     name  age address       phone
# sn
# 2   hari   23     pkr  9876273743
# 4    ram   21     ktm  9846363733

# %%
import pandas as pd 
df = pd.read_csv('datas.csv',index_col = 'sn')
data = df[df ['age'] > 35]
data.to_csv('new_data.csv')

# %%
import pandas as pd
data = {'Name':['Ram','Shyam','Hari'],
       'Age':[23,45,32],
       'Address' :['ktm','pkr','bkt']}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Address
# 0    Ram   23     ktm
# 1  Shyam   45     pkr
# 2   Hari   32     bkt

# %%
import csv
data = [['name','age','address'],
        ['Ram',34,'ktm'],
        ['Hari',22,'pkr'],
        ['shyam',44,'bkt']]
f = open('list_data.csv','w')
x = csv.writer(f)
for i in data:
    x.writerow(i)
    
    
    
f.close()

# %%
import pandas as pd
df = pd.read_csv('list_data.csv')
df
# Out:
#     name  age address
# 0    Ram   34     ktm
# 1   Hari   22     pkr
# 2  shyam   44     bkt
